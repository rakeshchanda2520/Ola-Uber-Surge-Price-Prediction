# %%
import random
import pandas as pd

# %%
df = pd.read_csv('cab_rides.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 693071 entries, 0 to 693070
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   distance          693071 non-null  float64
#  1   cab_type          693071 non-null  object
#  2   time_stamp        693071 non-null  int64
#  3   destination       693071 non-null  object
#  4   source            693071 non-null  object
#  5   price             637976 non-null  float64
#  6   surge_multiplier  693071 non-null  float64
#  7   id                693071 non-null  object
#  8   product_id        693071 non-null  object
#  9   name              693071 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 52.9+ MB

# %%
df
# Out:
#         distance cab_type     time_stamp    destination            source  \
# 0           0.44     Lyft  1544952607890  North Station  Haymarket Square
# 1           0.44     Lyft  1543284023677  North Station  Haymarket Square
# 2           0.44     Lyft  1543366822198  North Station  Haymarket Square
# 3           0.44     Lyft  1543553582749  North Station  Haymarket Square
# 4           0.44     Lyft  1543463360223  North Station  Haymarket Square
# ...          ...      ...            ...            ...               ...
# 693066      1.00     Uber  1543708385534      North End          West End
# 693067      1.00     Uber  1543708385534      North End          West End
# 693068      1.00     Uber  1543708385534      North End          West End
# 693069      1.00     Uber  1543708385534      North End          West End
# 693070      1.00     Uber  1543708385534      North End          West End
#
#         price  surge_multiplier                                    id  \
# ...

# %%
listOfNumbers = []
for x in range (0, 10000):
    listOfNumbers.append(random.randint(0, 693070))

# %%
listOfNumbers = list(set(listOfNumbers))

# %%
listOfNumbers
# Out:
# [196609,
#  131086,
#  393232,
#  360467,
#  65561,
#  31,
#  393249,
#  327731,
#  688180,
#  589877,
#  131128,
#  65596,
#  589889,
#  360514,
#  65602,
#  458818,
#  294981,
#  163905,
#  589897,
#  688203,
#  65622,
#  360541,
#  688221,
#  196703,
#  65635,
#  524387,
#  327784,
#  131178,
#  115,
#  360570,
#  524421,
#  360586,
#  491659,
#  557202,
#  229523,
#  524437,
#  557206,
#  32920,
#  196770,
#  688292,
#  165,
#  65702,
#  196789,
#  131259,
#  688318,
#  32961,
#  196802,
#  164034,
#  200,
#  622795,
#  196816,
#  196818,
#  164050,
#  458964,
#  655571,
#  655580,
#  262373,
#  295142,
#  295143,
#  426215,
#  360681,
#  557285,
#  655599,
#  590074,
#  360700,
#  688386,
#  360706,
#  622854,
#  264,
#  524552,
#  655639,
#  426269,
#  98590,
#  65822,
#  590112,
#  33059,
#  295205,
#  491817,
#  590122,
#  262443,
#  131378,
#  309,
#  491831,
#  459065,
#  557369,
#  590140,
#  318,
#  229694,
#  459072,
#  622910,
#  360773,
#  98637,
#  33102,
#  65877,
# ...

# %%
for i in listOfNumbers:
    df['distance'][i] = str(df['distance'][i] * 1.609344) + " km"
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_2500\335059266.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['distance'][i] = str(df['distance'][i] * 1.609344) + " km"

# %%
df.to_csv('cab_rides.csv')

# %%
for i in range(0,693070):
    if type(df['distance'][i]) == str:
#         print(df['distance'][i])
        num_list = df['distance'][i].split(" ")
        df['distance'][i] = float(num_list[0])

# %%
for i in range(0,693070):
     if type(df['distance'][i]) == str:
            print(i)

# %%
df = pd.read_csv("new_cheak.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 637976 entries, 0 to 637975
# Data columns (total 17 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0.1      637976 non-null  int64
#  1   index             637976 non-null  int64
#  2   Unnamed: 0        637976 non-null  int64
#  3   distance          637976 non-null  float64
#  4   cab_type          637976 non-null  object
#  5   time_stamp        637976 non-null  int64
#  6   destination       637976 non-null  object
#  7   source            637976 non-null  object
#  8   price             637976 non-null  float64
#  9   surge_multiplier  637976 non-null  float64
#  10  id                637976 non-null  object
#  11  product_id        637976 non-null  object
#  12  name              637976 non-null  object
#  13  date_time         637976 non-null  object
#  14  date              637976 non-null  object
#  15  day               637976 non-null  int64
# ...
