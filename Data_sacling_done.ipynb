# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('Merged_final_dataset.csv')

# %%
df
# Out:
#         Unnamed: 0.1  Unnamed: 0  distance cab_type     time_stamp  \
# 0                  0           0      1.45     Lyft  1545150004105
# 1                  1           1      4.17     Lyft  1545149713527
# 2                  2           2      2.61     Uber  1545152108275
# 3                  3           3      2.41     Lyft  1545151204098
# 4                  4           4      1.45     Lyft  1545150004105
# ...              ...         ...       ...      ...            ...
# 293159        293159      293159      2.30     Lyft  1543203646421
# 293160        293160      293160      2.30     Lyft  1543203646421
# 293161        293161      293161      2.19     Uber  1543203646358
# 293162        293162      293162      2.19     Uber  1543203646358
# 293163        293163      293163      2.19     Uber  1543203646358
#
#                                 destination                   source  price  \
# 0                 Back+Bay,+Boston,+MA,+USA  Northeastern University    5.0
# ...

# %%
df.drop(df.columns[[0,1]],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['distance', 'cab_type', 'time_stamp', 'destination', 'source', 'price',
#        'surge_multiplier', 'id', 'product_id', 'name', 'date_time', 'date',
#        'day', 'hour', 'fare_per_mile', 'class_hour', 'new_price',
#        'traveling_time', 'max_travel_time', 'min_travel_time',
#        'avg_travel_time', 'merge_date', 'temp', 'clouds', 'pressure', 'rain',
#        'humidity', 'wind'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293164 entries, 0 to 293163
# Data columns (total 28 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   distance          293164 non-null  float64
#  1   cab_type          293164 non-null  object
#  2   time_stamp        293164 non-null  int64
#  3   destination       293164 non-null  object
#  4   source            293164 non-null  object
#  5   price             293164 non-null  float64
#  6   surge_multiplier  293164 non-null  float64
#  7   id                293164 non-null  object
#  8   product_id        293164 non-null  object
#  9   name              293164 non-null  object
#  10  date_time         293164 non-null  object
#  11  date              293164 non-null  object
#  12  day               293164 non-null  int64
#  13  hour              293164 non-null  int64
#  14  fare_per_mile     293164 non-null  float64
#  15  class_hour        293164 non-null  int64
# ...

# %%
# df_lyft=df[df['cab_type']=="Lyft"]
# df_uber=df[df['cab_type']=="Uber"]

# %%
# df.drop(df.columns[[0]], axis=1, inplace=True)
df.columns
# Out:
# Index(['distance', 'cab_type', 'time_stamp', 'destination', 'source', 'price',
#        'surge_multiplier', 'id', 'product_id', 'name', 'date_time', 'date',
#        'day', 'hour', 'fare_per_mile', 'class_hour', 'new_price',
#        'traveling_time', 'max_travel_time', 'min_travel_time',
#        'avg_travel_time', 'merge_date', 'temp', 'clouds', 'pressure', 'rain',
#        'humidity', 'wind'],
#       dtype='object')

# %%
dff=df[["distance",'avg_travel_time','temp','clouds','pressure','rain','humidity','wind']]

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 293164 entries, 0 to 293163
# Data columns (total 8 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   distance         293164 non-null  float64
#  1   avg_travel_time  293164 non-null  float64
#  2   temp             293164 non-null  float64
#  3   clouds           293164 non-null  float64
#  4   pressure         293164 non-null  float64
#  5   rain             293164 non-null  float64
#  6   humidity         293164 non-null  float64
#  7   wind             293164 non-null  float64
# dtypes: float64(8)
# memory usage: 17.9 MB

# %%
from sklearn.preprocessing import StandardScaler

scalar=StandardScaler()

dff=scalar.fit_transform(dff)


dff = pd.DataFrame(dff, columns=[
  "distance",'avg_travel_time','temp','clouds','pressure','rain','humidity','wind'])

# %%
dff
# Out:
#         distance  avg_travel_time      temp    clouds  pressure      rain  \
# 0      -0.646748        -0.240554 -1.558765 -1.182438  0.099482 -0.213603
# 1       1.748797         3.052229 -1.558765 -1.182438  0.099482 -0.213603
# 2       0.374881         0.935440 -1.558765 -1.182438  0.099482 -0.213603
# 3       0.198738         0.817840 -1.558765 -1.182438  0.099482 -0.213603
# 4      -0.646748        -0.240554 -1.558765 -1.182438  0.099482 -0.213603
# ...          ...              ...       ...       ...       ...       ...
# 293159  0.101860        -1.534148  0.278701  0.642011  0.315441 -0.213603
# 293160  0.101860        -1.534148  0.278701  0.642011  0.315441 -0.213603
# 293161  0.004981        -0.240554  0.278701  0.642011  0.315441 -0.213603
# 293162  0.004981        -0.240554  0.278701  0.642011  0.315441 -0.213603
# 293163  0.004981        -0.240554  0.278701  0.642011  0.315441 -0.213603
#
#         humidity      wind
# 0      -2.237593  2.063766
# ...

# %%
df_lyft.drop(["distance",'avg_travel_time','temp','clouds','pressure','rain','humidity','wind'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [17], line 1
# ----> 1 df_lyft.drop(["distance",'avg_travel_time','temp','clouds','pressure','rain','humidity','wind'], axis=1, inplace=True)
#
# NameError: name 'df_lyft' is not defined

# %%
df
# Out:
#         distance cab_type     time_stamp                          destination  \
# 0           1.45     Lyft  1545150004105            Back+Bay,+Boston,+MA,+USA
# 1           4.17     Lyft  1545149713527  Financial+District,+Boston,+MA,+USA
# 2           2.61     Uber  1545152108275         Beacon+Hill,+Boston,+MA,+USA
# 3           2.41     Lyft  1545151204098         Beacon+Hill,+Boston,+MA,+USA
# 4           1.45     Lyft  1545150004105            Back+Bay,+Boston,+MA,+USA
# ...          ...      ...            ...                                  ...
# 293159      2.30     Lyft  1543203646421   Boston+University,+Boston,+MA,+USA
# 293160      2.30     Lyft  1543203646421   Boston+University,+Boston,+MA,+USA
# 293161      2.19     Uber  1543203646358           North+End,+Boston,+MA,+USA
# 293162      2.19     Uber  1543203646358           North+End,+Boston,+MA,+USA
# 293163      2.19     Uber  1543203646358           North+End,+Boston,+MA,+USA
#
# ...

# %%
result = pd.concat([dff, df], axis=1, join='inner')

# %%
result
# Out:
#         distance avg_travel_time      temp    clouds  pressure      rain  \
# 0      -0.646748       -0.240554 -1.558765 -1.182438  0.099482 -0.213603
# 1       1.748797        3.052229 -1.558765 -1.182438  0.099482 -0.213603
# 2       0.374881        0.935440 -1.558765 -1.182438  0.099482 -0.213603
# 3       0.198738        0.817840 -1.558765 -1.182438  0.099482 -0.213603
# 4      -0.646748       -0.240554 -1.558765 -1.182438  0.099482 -0.213603
# ...          ...             ...       ...       ...       ...       ...
# 293159  0.101860       -1.534148  0.278701  0.642011  0.315441 -0.213603
# 293160  0.101860       -1.534148  0.278701  0.642011  0.315441 -0.213603
# 293161  0.004981       -0.240554  0.278701  0.642011  0.315441 -0.213603
# 293162  0.004981       -0.240554  0.278701  0.642011  0.315441 -0.213603
# 293163  0.004981       -0.240554  0.278701  0.642011  0.315441 -0.213603
#
#         humidity      wind  distance cab_type  ...  max_travel_time  \
# ...

# %%
result.to_csv('scaled.csv')

# %%
# df.info()        #       2,3,4,5,7,8,10,11,13,14,17,18,19,21

# %%
# df.drop(df.columns[[0,1,3,4,5,6,7]],axis=1,inplace=True)

# %%
# from statsmodels.stats.outliers_influence import variance_inflation_factor

# vif_data = pd.DataFrame()
# vif_data["feature"] = df.columns
  
# # calculating VIF for each feature
# vif_data["VIF"] = [variance_inflation_factor(df.values, i)
#                           for i in range(len(df.columns))]
  
# print(vif_data)

# %%
# from sklearn.preprocessing import LabelEncoder

# df['cab_type']=LabelEncoder().fit_transform(df['cab_type'])
# df['name']=LabelEncoder().fit_transform(df['name'])

# %%
# df.corr()
