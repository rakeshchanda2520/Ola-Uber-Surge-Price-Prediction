# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("Merged_final_dataset.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'distance', 'cab_type', 'time_stamp', 'destination',
#        'source', 'price', 'surge_multiplier', 'id', 'product_id', 'name',
#        'date_time', 'date', 'day', 'hour', 'fare_per_mile', 'class_hour',
#        'new_price', 'traveling_time', 'max_travel_time', 'min_travel_time',
#        'avg_travel_time', 'merge_date', 'temp', 'clouds', 'pressure', 'rain',
#        'humidity', 'wind'],
#       dtype='object')

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['distance', 'cab_type', 'time_stamp', 'destination', 'source', 'price',
#        'surge_multiplier', 'id', 'product_id', 'name', 'date_time', 'date',
#        'day', 'hour', 'fare_per_mile', 'class_hour', 'new_price',
#        'traveling_time', 'max_travel_time', 'min_travel_time',
#        'avg_travel_time', 'merge_date', 'temp', 'clouds', 'pressure', 'rain',
#        'humidity', 'wind'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['distance', 'cab_type', 'time_stamp', 'destination', 'source', 'price',
#        'surge_multiplier', 'id', 'product_id', 'name', 'date_time', 'date',
#        'day', 'hour', 'fare_per_mile', 'class_hour', 'new_price',
#        'traveling_time', 'max_travel_time', 'min_travel_time',
#        'avg_travel_time', 'merge_date', 'temp', 'clouds', 'pressure', 'rain',
#        'humidity', 'wind'],
#       dtype='object')

# %%
df.cab_type.value_counts()  # data is alanced for each cab type
# Out:
# Uber    151136
# Lyft    142028
# Name: cab_type, dtype: int64

# %%
df.destination.value_counts()    # all destinaton are same likely to occur
# Out:
# Financial+District,+Boston,+MA,+USA         24983
# North+Station,+Boston,+MA,+USA              24731
# Haymarket+Square,+Boston,+MA,+USA           24701
# Beacon+Hill,+Boston,+MA,+USA                24465
# Northeastern+University,+Boston,+MA,+USA    24463
# Theatre+District,+Boston,+MA,+USA           24449
# Fenway,+Boston,+MA,+USA                     24415
# Back+Bay,+Boston,+MA,+USA                   24380
# West+End,+Boston,+MA,+USA                   24346
# North+End,+Boston,+MA,+USA                  24269
# South+Station,+Boston,+MA,+USA              23984
# Boston+University,+Boston,+MA,+USA          23978
# Name: destination, dtype: int64

# %%
df.source.value_counts()         # all source are same likely to occur
# Out:
# Financial District         25550
# North End                  25066
# Theatre District           25063
# Fenway                     24898
# Back Bay                   24575
# South Station              24510
# Boston University          24489
# Haymarket Square           24450
# West End                   24328
# Northeastern University    23941
# Beacon Hill                23560
# North Station              22734
# Name: source, dtype: int64

# %%
df.hour.value_counts().sort_index()
# Out:
# 0     13806
# 1     11507
# 2     12259
# 3     11858
# 4     12093
# 5     10822
# 6     10871
# 7     10486
# 8     10155
# 9     12510
# 10    12539
# 11    13031
# 12    13071
# 13    12882
# 14    12617
# 15    12854
# 16    13260
# 17    12907
# 18    12553
# 19    11364
# 20    11680
# 21    11745
# 22    12423
# 23    13871
# Name: hour, dtype: int64

# %%
df.class_hour.value_counts().sort_index()
# Out:
# 0    37572
# 1    34773
# 2    31512
# 3    38080
# 4    38570
# 5    39021
# 6    35597
# 7    38039
# Name: class_hour, dtype: int64

# %%
df_lyft=df[df['cab_type']=="Lyft"]
df_uber=df[df['cab_type']=="Uber"]

# %%
df_lyft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 142028 entries, 0 to 293160
# Data columns (total 28 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   distance          142028 non-null  float64
#  1   cab_type          142028 non-null  object
#  2   time_stamp        142028 non-null  int64
#  3   destination       142028 non-null  object
#  4   source            142028 non-null  object
#  5   price             142028 non-null  float64
#  6   surge_multiplier  142028 non-null  float64
#  7   id                142028 non-null  object
#  8   product_id        142028 non-null  object
#  9   name              142028 non-null  object
#  10  date_time         142028 non-null  object
#  11  date              142028 non-null  object
#  12  day               142028 non-null  int64
#  13  hour              142028 non-null  int64
#  14  fare_per_mile     142028 non-null  float64
#  15  class_hour        142028 non-null  int64
# ...

# %%
df_uber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 151136 entries, 2 to 293163
# Data columns (total 28 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   distance          151136 non-null  float64
#  1   cab_type          151136 non-null  object
#  2   time_stamp        151136 non-null  int64
#  3   destination       151136 non-null  object
#  4   source            151136 non-null  object
#  5   price             151136 non-null  float64
#  6   surge_multiplier  151136 non-null  float64
#  7   id                151136 non-null  object
#  8   product_id        151136 non-null  object
#  9   name              151136 non-null  object
#  10  date_time         151136 non-null  object
#  11  date              151136 non-null  object
#  12  day               151136 non-null  int64
#  13  hour              151136 non-null  int64
#  14  fare_per_mile     151136 non-null  float64
#  15  class_hour        151136 non-null  int64
# ...

# %%
df_lyft.name.value_counts()
# Out:
# Shared          23698
# Lux             23698
# Lux Black XL    23686
# Lyft XL         23654
# Lux Black       23651
# Lyft            23641
# Name: name, dtype: int64

# %%
df_uber.name.value_counts()
# Out:
# UberPool     25260
# WAV          25215
# UberX        25208
# UberXL       25159
# Black SUV    25150
# Black        25144
# Name: name, dtype: int64

# %%
df_lyft.product_id.value_counts()
# Out:
# lyft_line       23698
# lyft_premier    23698
# lyft_luxsuv     23686
# lyft_plus       23654
# lyft_lux        23651
# lyft            23641
# Name: product_id, dtype: int64

# %%
df_uber.product_id.value_counts()
# Out:
# 997acbb5-e102-41e1-b155-9df7de0a73f2    25260
# 9a0e7b09-b92b-4c41-9779-2ad22b4d779d    25215
# 55c66225-fbe7-4fd5-9072-eab1ece5e23e    25208
# 6f72dfc5-27f1-42e8-84db-ccc7a75f6969    25159
# 6d318bcc-22a3-4af6-bddd-b409bfce1546    25150
# 6c84fd89-3f11-4782-9b50-97c468b19529    25144
# Name: product_id, dtype: int64

# %% [markdown]
# ### Checking Outliers

# %%
sns.set(rc={'figure.figsize':(5,5)}),
sns.boxplot(df['distance'])
# Out:
# <AxesSubplot: >

# %%
sns.set(rc={'figure.figsize':(5,5)}),

sns.boxplot(df['new_price'])
# Out:
# <AxesSubplot: >

# %%
sns.set(rc={'figure.figsize':(5,5)}),

sns.boxplot(df['avg_travel_time'])
# Out:
# <AxesSubplot: >

# %%
sns.set(rc={'figure.figsize':(5,5)}),

sns.boxplot(df['pressure'])
# Out:
# <AxesSubplot: >

# %%
sns.set(rc={'figure.figsize':(5,5)}),

sns.boxplot(df['wind'])
# Out:
# <AxesSubplot: >

# %%
sns.set(rc={'figure.figsize':(5,5)}),

sns.boxplot(df['temp'])
# Out:
# <AxesSubplot: >

# %%
sns.set(rc={'figure.figsize':(5,5)}),

sns.boxplot(df['clouds'])
# Out:
# <AxesSubplot: >

# %%
sns.set(rc={'figure.figsize':(5,5)}),

sns.boxplot(df['rain'])
# Out:
# <AxesSubplot: >

# %%
sns.set(rc={'figure.figsize':(5,5)}),

sns.boxplot(df['humidity'])
# Out:
# <AxesSubplot: >

# %% [markdown]
# ### Histogram And PDF for Continuous Data

# %%
sns.set(rc={'figure.figsize':(10,10)}),

sns.distplot(df['distance'],kde=True)
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_12256\2864753567.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['distance'],kde=True)
# <AxesSubplot: xlabel='distance', ylabel='Density'>

# %%
sns.distplot(df_lyft['distance'],kde=True)
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_12256\4120484805.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_lyft['distance'],kde=True)
# <AxesSubplot: xlabel='distance', ylabel='Density'>

# %%
sns.distplot(df_uber['distance'],kde=True)
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_12256\3208426284.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_uber['distance'],kde=True)
# <AxesSubplot: xlabel='distance', ylabel='Density'>

# %%
sns.distplot(df['new_price'],kde=True)
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_12256\2598670828.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['new_price'],kde=True)
# <AxesSubplot: xlabel='new_price', ylabel='Density'>

# %%
sns.distplot(df_lyft['new_price'],kde=True)
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_12256\2234805900.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_lyft['new_price'],kde=True)
# <AxesSubplot: xlabel='new_price', ylabel='Density'>

# %%
sns.distplot(df_uber['new_price'],kde=True)
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_12256\2332188439.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_uber['new_price'],kde=True)
# <AxesSubplot: xlabel='new_price', ylabel='Density'>

# %%
sns.distplot(df['avg_travel_time'],kde=True)
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_12256\1271338448.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['avg_travel_time'],kde=True)
# <AxesSubplot: xlabel='avg_travel_time', ylabel='Density'>

# %%
sns.distplot(df_lyft['avg_travel_time'],kde=True)
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_12256\810319421.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_lyft['avg_travel_time'],kde=True)
# <AxesSubplot: xlabel='avg_travel_time', ylabel='Density'>

# %%
sns.distplot(df_uber['avg_travel_time'],kde=True)
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_12256\3849840602.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_uber['avg_travel_time'],kde=True)
# <AxesSubplot: xlabel='avg_travel_time', ylabel='Density'>

# %%
sns.distplot(df['pressure'],kde=True)
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_12256\2771605211.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['pressure'],kde=True)
# <AxesSubplot: xlabel='pressure', ylabel='Density'>

# %%
sns.distplot(df['wind'],kde=True)
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_12256\2456853784.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['wind'],kde=True)
# <AxesSubplot: xlabel='wind', ylabel='Density'>

# %%
sns.distplot(df['temp'],kde=True)
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_12256\3171180000.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['temp'],kde=True)
# <AxesSubplot: xlabel='temp', ylabel='Density'>

# %%
sns.distplot(df['clouds'],kde=True)
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_12256\875887928.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['clouds'],kde=True)
# <AxesSubplot: xlabel='clouds', ylabel='Density'>

# %%
sns.distplot(df['rain'],kde=True)
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_12256\4115357053.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['rain'],kde=True)
# <AxesSubplot: xlabel='rain', ylabel='Density'>

# %%
sns.distplot(df['humidity'],kde=True)
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_12256\3929382798.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['humidity'],kde=True)
# <AxesSubplot: xlabel='humidity', ylabel='Density'>

# %% [markdown]
# ### Count plot for Categorical Data

# %%
ax=sns.countplot(y="source",data=df)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '23941'),
#  Text(0, 0, '24450'),
#  Text(0, 0, '24489'),
#  Text(0, 0, '22734'),
#  Text(0, 0, '24328'),
#  Text(0, 0, '25550'),
#  Text(0, 0, '24510'),
#  Text(0, 0, '25066'),
#  Text(0, 0, '24575'),
#  Text(0, 0, '24898'),
#  Text(0, 0, '25063'),
#  Text(0, 0, '23560')]

# %%
ax=sns.countplot(y="destination",data=df)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '24380'),
#  Text(0, 0, '24983'),
#  Text(0, 0, '24465'),
#  Text(0, 0, '24346'),
#  Text(0, 0, '24449'),
#  Text(0, 0, '24731'),
#  Text(0, 0, '24701'),
#  Text(0, 0, '24463'),
#  Text(0, 0, '23984'),
#  Text(0, 0, '23978'),
#  Text(0, 0, '24415'),
#  Text(0, 0, '24269')]

# %%
ax=sns.countplot(y="cab_type",data=df)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '142028'), Text(0, 0, '151136')]

# %%
ax=sns.countplot(y="product_id",data=df_lyft)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '23698'),
#  Text(0, 0, '23641'),
#  Text(0, 0, '23698'),
#  Text(0, 0, '23686'),
#  Text(0, 0, '23654'),
#  Text(0, 0, '23651')]

# %%
ax=sns.countplot(y="product_id",data=df_uber)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '25260'),
#  Text(0, 0, '25215'),
#  Text(0, 0, '25150'),
#  Text(0, 0, '25159'),
#  Text(0, 0, '25208'),
#  Text(0, 0, '25144')]

# %%
ax=sns.countplot(y="day",data=df)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '53039'),
#  Text(0, 0, '52184'),
#  Text(0, 0, '31180'),
#  Text(0, 0, '42571'),
#  Text(0, 0, '38043'),
#  Text(0, 0, '37733'),
#  Text(0, 0, '38414')]

# %%
ax=sns.countplot(y="class_hour",data=df)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '37572'),
#  Text(0, 0, '34773'),
#  Text(0, 0, '31512'),
#  Text(0, 0, '38080'),
#  Text(0, 0, '38570'),
#  Text(0, 0, '39021'),
#  Text(0, 0, '35597'),
#  Text(0, 0, '38039')]

# %%
ax=sns.countplot(y="hour",data=df)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '13806'),
#  Text(0, 0, '11507'),
#  Text(0, 0, '12259'),
#  Text(0, 0, '11858'),
#  Text(0, 0, '12093'),
#  Text(0, 0, '10822'),
#  Text(0, 0, '10871'),
#  Text(0, 0, '10486'),
#  Text(0, 0, '10155'),
#  Text(0, 0, '12510'),
#  Text(0, 0, '12539'),
#  Text(0, 0, '13031'),
#  Text(0, 0, '13071'),
#  Text(0, 0, '12882'),
#  Text(0, 0, '12617'),
#  Text(0, 0, '12854'),
#  Text(0, 0, '13260'),
#  Text(0, 0, '12907'),
#  Text(0, 0, '12553'),
#  Text(0, 0, '11364'),
#  Text(0, 0, '11680'),
#  Text(0, 0, '11745'),
#  Text(0, 0, '12423'),
#  Text(0, 0, '13871')]

# %%
df.corr()
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_12256\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                   distance  time_stamp     price  surge_multiplier       day  \
# distance          1.000000    0.007044  0.346380          0.024392  0.001989
# time_stamp        0.007044    1.000000  0.002500          0.000135  0.190089
# price             0.346380    0.002500  1.000000          0.243610 -0.000749
# surge_multiplier  0.024392    0.000135  0.243610          1.000000 -0.003940
# day               0.001989    0.190089 -0.000749         -0.003940  1.000000
# hour              0.005961   -0.035881  0.003238          0.003785 -0.008332
# fare_per_mile    -0.287343   -0.003518  0.225053          0.057829  0.000441
# ...

# %%
sns.set(rc={'figure.figsize':(20,20)})
df_corr = df.corr()
print(sns.heatmap(df_corr,annot=True))
plt.title("CORRELATION BETWEEN VARIABLES")
# Out:
# C:\Users\RAHUL\AppData\Local\Temp\ipykernel_12256\1227018412.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_corr = df.corr()
# AxesSubplot(0.125,0.11;0.62x0.77)
# Text(0.5, 1.0, 'CORRELATION BETWEEN VARIABLES')
